# %%
from ultralytics import YOLO

# %%
model = YOLO("../models/hand-trained.pt")

# %%
results = model("../data/random_palm.jpg")
# Out:
# image 1/1 d:\Projects\npu-gesture-control\old_misc\notebooks\..\data\random_palm.jpg: 224x192 1 hand, 39.0ms
# Speed: 0.8ms preprocess, 39.0ms inference, 1.2ms postprocess per image at shape (1, 3, 224, 192)

# %%
for result in results:
    result.show()
