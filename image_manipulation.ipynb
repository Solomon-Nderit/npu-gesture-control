# %%
import cv2

# %%
image = cv2.imread("images/8k_plane_wreck.jpg")

# %%
type(image)
# Out:
# numpy.ndarray

# %%
image.shape
# Out:
# (4912, 7633, 3)

# %%
#Convert image from a 1D to a 2D array
img.shape = (img.size // COLS, COLS)
print(img.shape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 2
#       1 #Convert image from a 1D to a 2D array
# ----> 2 img.shape = (img.size // COLS, COLS)
#       3 print(img.shape)
#
# ValueError: cannot reshape array of size 9669 into shape (37,255)
